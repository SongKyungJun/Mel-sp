# %%
import selenium
from selenium import webdriver as wd
import time
import pandas as pd
from bs4 import BeautifulSoup
import requests
from itertools import repeat

# %%
# 크롬드라이버 열기
driver = wd.Chrome('C:/Users/Administrator/jpnt/Min_Pj/chromedriver') # 크롬드라이버 경로
#driver.maximize_window() # 크롬창 크기 최대

# 드라이버가 해당 url 접속
url = 'https://www.melon.com/chart/index.htm' # 멜론차트 페이지
driver.get(url)

# 차트파인더 클릭
driver.find_element_by_xpath('//*[@id="gnb_menu"]/ul[1]/li[1]/div/div/button/span').click()

# 연대선택, 연도선택, 장르선택

# 차트선택 클릭
driver.find_element_by_xpath('//*[@id="d_chart_search"]/div/h4[3]/a').click()
time.sleep(2)

# 연대선택 
driver.find_element_by_xpath('//*[@id="d_chart_search"]/div/div/div[1]/div[1]/ul/li[3]/span/label').click()
time.sleep(2)

# 연도선택
driver.find_element_by_xpath('//*[@id="d_chart_search"]/div/div/div[2]/div[1]/ul/li[10]/span/label').click()
time.sleep(2)


# 장르선택
driver.find_element_by_xpath('//*[@id="d_chart_search"]/div/div/div[5]/div[1]/ul/li[1]/span/label').click()
time.sleep(2)

# 검색버튼 클릭
driver.find_element_by_xpath('//*[@id="d_srch_form"]/div[2]/button/span/span').click()

# %%
title=driver.find_elements_by_class_name('ellipsis.rank01')

title2=[]
for i in title:
    title2.append(i.text)

# %%
#del title2[0]
del title2[50:]

# %%
singer=driver.find_elements_by_class_name('ellipsis.rank02')
singer2=[]


for i in singer:
    singer2.append(i.text)


#del singer2[0]
del singer2[50:]


songTagList = driver.find_elements_by_class_name('input_check')
number=[]
for i in songTagList:
    number.append(i.get_attribute('value'))

del number[0]
del number[50:]    

LYRIC=[]
for i in number:
    driver.get("https://www.melon.com/song/detail.htm?songId=" + i)
    lyric=driver.find_element_by_class_name("lyric")
    LYRIC.append(lyric.text)

# %%
len(title2)
# Out:
# 50

# %%
len(singer2)
# Out:
# 50

# %%
len(LYRIC)
# Out:
# 50

# %%
df=pd.DataFrame({"제목":title2,"가수":singer2,"가사":LYRIC})

# %%
df.to_excel("멜론 2000 Top50.xlsx",  encoding='utf-8')

# %%
df
# Out:
#                                 제목           가수  \
# 0                             아시나요          조성모
# 1            다 줄거야 (Acoustic Ver.)          조규만
# 2                       Run To You       DJ DOC
# 3                              거짓말          god
# 4   초련(初戀) (Techno Mix) (Feat. 윤진)           클론
# 5                             가시나무          조성모
# 6                           흔들린 우정          홍경민
# 7                        나의 연인(我戀)          임창정
# 8                               영원          스카이
# 9                                멍          김현정
# 10                           오! 가니       컨츄리 꼬꼬
# 11                              기도          정일영
# 12                      전설속의 누군가처럼          신승훈
# 13                           너를 위해          임재범
# 14                              바보          박효신
# 15                         그대가 그대를          이승환
# 16                       매직 카펫 라이드          자우림
# 17                          중독된 사랑          조장혁
# 18                       해줄 수 없는 일          박효신
# 19                              고백          박혜경
# 20                  비(悲)의 Rhapsody          최재훈
# 21                            Love          윤현석
# 22                        오랜 방황의 끝          김태영
# 23                      Day By Day  플라이 투 더 스카이
# 24                           Tears          소찬휘
# 25                              상실          박상민
# 26                          잘됐어!!!            샵
# 27                Lie (Radio Ver.)         박화요비
# 28                            어제처럼           제이
# 29                          와인(迗人)          김경호
# 30                              바꿔          이정현
# 31           그대니까요 (Duet With 차은주)          김현철
# 32                               와          이정현
# 33                        One Love          원타임
# 34                           요즘 너는          이현우
# 35                             서방님          이소은
# 36                          맥주와 땅콩     쿨 (COOL)
# 37                       I Believe          이수영
# 38                          애수(哀愁)          god
# 39                     Cyber Lover           터보
# 40                          머피의 법칙       DJ DOC
# 41                          너를 보내고           YB
# 42                             부메랑          김건모
# 43                       Sad Salsa          백지영
# 44                    힘을 내요, 미스터 김       롤러 코스터
# 45                             성인식          박지윤
# 46                          울트라맨이야          서태지
# 47                        Blue Sky          박기영
# 48                              사슬          서문탁
# 49                           Annie          윤종신
#
#                                                    가사
# 0   아시나요 얼마나 사랑했는지 그댈 보면 자꾸 눈물이 나서\n차마 그대 바라보지 못하고...
# 1   그대 내게 다가오는 그 모습\n자꾸 다시 볼수 없을 것만 같아서\n감은 두눈 뜨지 ...
# 2   하나 투 원 투 쓰리 포\nBOUNCE with me BOUNCE\nwith me\...
# 3   미안해\n난 니가 싫어졌어 우리\n이만 헤어져\n다른 여자가 생겼어 너보다\n훨씬 ...
# 4   난 그냥 좋았어 니 앞에만 서면\n요즘 내가 왜 이러는지 나도 몰라\n니 생각만 하...
# 5   내 속엔 내가 너무도 많아\n당신의 쉴곳 없네\n내 속엔 헛된 바램들로\n당신의 편...
# 6   아냐 이게 아닌데 왜 난 자꾸만\n친구의 여자가 좋을까\n이러면 안되지 하면서 왜\...
# 7   너를 알기 전에 나 어떻게 혼자 살아 왔을까\n\n너 없는 세상 이렇게도 내게 눈물...
# 8   너와의 행복했었던\n또 아름다웠던 추억\n우연히 지나친\n그런 시간만은 아닐 꺼야\...
# 9   너 나를 쉽게 봤어\n그렇지 않니\n너는 몰라 너무 몰라 사랑을\n안돼 니 맘대로 ...
# 10  오오 오오\n우리 오다가다 만난사이\n아니잖아\n우리그냥 보통사이 아니잖아\n그러면...
# 11  혹시 나를 떠나려는 그대 맘이\n힘든 나를 위해서 그런 이유인가요\n하루만큼 멀어져...
# 12  거울 속의 그대 모습을 바라본적 있는가\n부끄럽지 않은 삶인가 뜨거운 눈물 흘려본 ...
# 13  어쩜 우린 복잡한 인연에\n서로 엉켜있는 사람인가봐\n나는 매일 네게 갚지도 못할만...
# 14  너무 모르고 있죠 이미 떠난 사인데\n언젠가 올 거란 생각에 마냥 웃고만 있죠\n슬...
# 15  참 많이 모질었었죠 나 당신께\n나같지 않은 말땜에 놀랬겠죠\n편할날이 없었죠 틀렸...
# 16  이렇게 멋진 파란 하늘 위로\n날으는 마법 융단을 타고\n이렇게 멋진 푸른 세상 속...
# 17  다시 너를 볼 수 있을까\n\n이렇게 너의 집까지 오고만 거야\n\n넌 나를 떠나도...
# 18  할말이 있어 어려운 얘기\n내게 힘겹게 꺼내놓은 네\n마지막 얘기\n내 곁에 있기엔...
# 19  말해야 하는데 네 앞에 서면\n\n아무 말 못하는 내가 미워져\n\n용기를 내야해 ...
