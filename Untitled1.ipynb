# %%
import pandas as pd

# %%
all_data = pd.read_excel('가요tag1.xlsx')
all_data
# Out:
#     Unnamed: 0                       Playlist  \
# 0            0      아름다운 우리 소리, 꼭 들어봐야 할 퓨전국악
# 1            1          아이돌계 최강 레이블, SM엔터테인먼트
# 2            2  교복 자율화 시대, 10대에게 사랑 받은 국내 아이돌
# 3            3         종현이 작사 작곡한 청춘과 삶의 이야기들
# 4            4       서정적 음색으로 1980년대 장식한 여가수들
# 5            5             1990년대를 빛낸 국내 혼성그룹
# 6            6          트로트계 중심에 우뚝 선 젊은 피 열풍
# 7            7        뮤지션 하림이 단독 작곡한 감성적인 멜로디
# 8            8       담백하고 독특한 캐럴! 메리 인디 크리스마스
# 9            9     동료 가수들에게 선사한 작곡가 김동률의 주요작들
# 10          10           유재하 음악경연대회 역대 수상곡 모음
# 11          11      표현력의 교과서, 이문세의 컬래버레이션 트랙들
# 12          12       1990년대를 지배한 마왕 신해철의 음악세계
# 13          13        한국 1세대 아이돌 보아의 한국어 히트곡들
# 14          14      두 아이콘의 음악 열전: 유희열 vs. 정재형
# 15          15          기타로 가꾸어낸 달콤한 어쿠스틱 멜로디
# 16          16          담백한 여백, 인디 포크 싱어송라이터들
# 17          17       포크 듀엣, 해바라기를 거쳐 간 이들의 음악
# 18          18         아련한 감성 발라드로 가창력 뽐낸 아이돌
# ...

# %%
Tag = all_data['PlTag']
Tag_v = Tag.values
Tag_v_l
# Out:
# [' 퓨전국악  크로스오버  가요  전통  매력  기분전환  국악',
#  ' 아이돌  SM  가요  댄스  레이블  에스엠',
#  ' 1980년대  아이돌  가요  1970_80  자유  명곡  회상  추억  틴에이저  10대',
#  ' 종현  송라이터  가요  2010년대  발라드  쓸쓸한  따스한  슬픈  차분한  감성',
#  ' 1980년대  여자가수  가요  1970_80  대중적  추억회상  향수  명곡  서정적  가창력',
#  ' 90년대  혼성그룹  가요  댄스  신나는  기분전환  레트로',
#  ' 트로트  성인가요  2000  2010  가요  전통가요  젊어진  신나는  댄스  차세대',
#  ' 작곡가  하림  가요  발라드  감성적인  명곡  따뜻한  추억  세련된  스타일',
#  ' 인디  캐럴  2010  가요  크리스마스  겨울  분위기',
#  ' 추억  가을  1990  가요  발라드  명곡  감성  회상  작곡가  김동률',
#  ' 유재하음악경연대회  수상곡  가요  유재하  실력파  신예  발라드',
#  ' 발라드  듀엣  가요  낭만  추억  컬래버레이션  감성  명곡  레전드  황제',
#  ' 영원한마왕  전설  1990  가요  국내록  legend  락  밴드',
#  ' 케이팝  보아  가요  댄스  BOA  히트곡  원조  한류  아이돌',
#  ' 라이벌  대표곡  2000  가요  발라드  원맨밴드  우정  작곡가  싱어송라이터',
#  ' 2010  차분한  가요  인디  잔잔한  가을  사랑  달콤함  기타  인디팝',
#  ' 인디  싱어송라이터  2010  가요  힐링  여유  포크  Folk  indie  감성',
#  ' 포크  해바라기  가요  1970_80  발라드  낭만  추억  통기타  이주호  유익종',
#  ' 발라드  아이돌  2010  가요  감성  아련  섬세한  실력파  잔잔한',
#  ' 라이벌  보컬  1990  2000  가요  발라드  패닉  전람회',
# ...

# %%
'''
all_data['PLTALL'] = all_data['PlTag']+all_data['PlTag.1']+all_data['PlTag.2']+all_data['PlTag.3']
+all_data['PlTag.4']+all_data['PlTag.5']+all_data['PlTag.6']+all_data['PlTag.7']
+all_data['PlTag.8']+all_data['PlTag.9']+all_data['PlTag.10']+all_data['PlTag.11']
+all_data['PlTag.12']+all_data['PlTag.13']+all_data['PlTag.14']+all_data['PlTag.15']
+all_data['PlTag.16']+all_data['PlTag.17']
all_data['PLTALL']
plt_all = all_data['PLTALL']
plt_all
'''
# Out:
# 0       퓨전국악  크로스오버  가요  전통  매력  기분전환  국악 인디  매직스트로베리...
# 1       퓨전국악  크로스오버  가요  전통  매력  기분전환  국악 인디  매직스트로베리...
# 2       퓨전국악  크로스오버  가요  전통  매력  기분전환  국악 인디  매직스트로베리...
# 3       퓨전국악  크로스오버  가요  전통  매력  기분전환  국악 인디  매직스트로베리...
# 4       퓨전국악  크로스오버  가요  전통  매력  기분전환  국악 인디  매직스트로베리...
#                              ...
# 605                                                  NaN
# 606                                                  NaN
# 607                                                  NaN
# 608                                                  NaN
# 609                                                  NaN
# Name: PLTALL, Length: 610, dtype: object

# %%
plt_all.dropna()
# Out:
# 0       퓨전국악  크로스오버  가요  전통  매력  기분전환  국악 인디  매직스트로베리...
# 1       퓨전국악  크로스오버  가요  전통  매력  기분전환  국악 인디  매직스트로베리...
# 2       퓨전국악  크로스오버  가요  전통  매력  기분전환  국악 인디  매직스트로베리...
# 3       퓨전국악  크로스오버  가요  전통  매력  기분전환  국악 인디  매직스트로베리...
# 4       퓨전국악  크로스오버  가요  전통  매력  기분전환  국악 인디  매직스트로베리...
#                              ...
# 420     케이팝  보아  가요  댄스  BOA  히트곡  원조  한류  아이돌 인디  슈가...
# 421     케이팝  보아  가요  댄스  BOA  히트곡  원조  한류  아이돌 추억  록발...
# 422     케이팝  보아  가요  댄스  BOA  히트곡  원조  한류  아이돌 추억  록발...
# 423     케이팝  보아  가요  댄스  BOA  히트곡  원조  한류  아이돌 추억  록발...
# 424     케이팝  보아  가요  댄스  BOA  히트곡  원조  한류  아이돌 추억  록발...
# Name: PLTALL, Length: 425, dtype: object
